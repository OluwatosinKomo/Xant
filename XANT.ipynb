# %% [markdown]
# This project is nicknamed **XANT**
#
# **Name: Oluwatosin Komolafe**
#
# **Title: Energy Consumption Model**
#
# **Project Description**
# The goal of this project is to develop a machine learning model that can predict energy consumption of appliances in smart homes.(Develop this further with an overview of energy efficiency and environmental challenges)
#
# **Aim**
# The project is aimed at providing an accurate prediction of future energy consumption patterns. This will help make informed decisions on energy use, hence contributing to sustainable lifestyle.This study will therefore utilize different algorithms to ascertain the most suitable model.
#
# **Possible Outcomes**
# This project is expected to provide a machine learning model that predicts accurate energy consumption of home appliances. This will help provide or enhance energy efficiency and help optimize appliance usage in a smart home. This will not only ensure environmental benefits, but will also provide economic and financial gains.

# %% [markdown]
# **Linear Regression**:
# Linear regression analysis is used to predict the value of a variable based on the value of another variable. The variable to be predicted is called the dependent variable. The variable you are using to predict the other variable's value is called the independent variable. This form of analysis estimates the coefficients of the linear equation, involving one or more independent variables that best predict the value of the dependent variable. Linear regression fits a straight line or surface that minimizes the discrepancies between predicted and actual output values. In linear regression, the value of Y (dependent variable) is derived from X (independent variable). In essence, linear regression attempts to model the relationship between two variables by fitting a linear equation to observed data.
#
# A linear regression line has an equation of the form **Y = a + bX**, where X is the independent variable and Y is the dependent variable. The slope of the line is b, and a is the intercept (the value of y when x = 0).
#
# Strengths of Linear Regression
# - Linear regression is straightforward to understand and explain,
# - Linear regression can be regularized to avoid overfitting.
# - Linear models can be updated easily with new data using stochastic gradient descent.
#
# Weaknesses of Linear Regression
# - Linear regression performs poorly when there are non-linear relationships.
# - They are not naturally flexible enough to capture more complex patterns,
# - Adding the right interaction terms or polynomials can be tricky and time-consuming.
#
# **Decison Trees**:
# A decision tree is a non-parametric supervised learning technique that can be used for both classification and regression problems. It has a hierarchical, tree structure, which consists of a root node, branches, internal nodes and leaf nodes. It is a tree-structured classifier, where internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome. A decision tree starts with a root node, which does not have any incoming branches. The outgoing branches from the root node then feed into the internal nodes, also known as decision nodes. Based on the available features, both node types conduct evaluations to form homogenous subsets, which are denoted by leaf nodes, or terminal nodes. The leaf nodes represent all the possible outcomes within the dataset.
#
# Decision Tree Terminologies
# - Root Node: Root node is from where the decision tree starts. It represents the entire dataset, which further gets divided into   two or more homogeneous sets.
# - Leaf Node: Leaf nodes are the final output node, and the tree cannot be segregated further after getting a leaf node.
# - Splitting: Splitting is the process of dividing the decision node/root node into sub-nodes according to the given conditions.
# - Branch/Sub Tree: A tree formed by splitting the tree.
# - Pruning: Pruning is the process of removing the unwanted branches from the tree.
# - Parent/Child node: The root node of the tree is called the parent node, and other nodes are called the child nodes.
#
# Strengths of Decision Trees
# - Easy to interpret
# - Little to no data preparation required
# - More flexible
#
# Weaknesses of Decision Trees
# - Prone to overfitting
# - High variance estimators
# - More expensive to train
# *- Not fully supported in scikit-learn
#
# **Differences Between Linear Regression and Decision Trees**
#
# Decision trees and linear regression are both machine learning techniques used for different types of problems. Here are the key differences between them:
#
# 1. Nature of Algorithm:
#
# - Decision Tree: Decision trees are a non-linear and non-parametric supervised learning algorithm. They can handle both           classification and regression tasks and are particularly useful when the relationships between features and the target           variable are non-linear or complex.
# - Linear Regression: Linear regression is a linear and parametric supervised learning algorithm primarily used for regression     tasks. It assumes a linear relationship between the features and the target variable.
#
# 2. Output:
#
# - Decision Tree: Decision trees provide a tree-like structure with a series of if-else conditions that lead to a final             prediction.
# - Linear Regression: Linear regression provides a linear equation that represents the relationship between the features and the   target variable.
#
# 3. Interpretability:
#
# - Decision Tree: Decision trees are highly interpretable and can be easily visualized, making it clear how decisions are made.
# - Linear Regression: Linear regression models are also interpretable, as you can directly see the coefficients and their impact   on the target variable.
#
# 4. Handling Non-Linearity:
#
# - Decision Tree: Decision trees can capture non-linear relationships effectively and are not limited by the assumption of         linearity.
# - Linear Regression: Linear regression assumes a linear relationship, so it may not perform well when the underlying data has     non-linear patterns.
#
# 5. Overfitting:
#
# - Decision Tree: Decision trees are prone to overfitting, especially when they are deep. Techniques like pruning and limiting     tree depth are used to mitigate this issue.
# - Linear Regression: Linear regression models are less prone to overfitting but can still be affected by outliers.
#
# Use Cases:
# - Decision Tree: Decision trees are suitable for tasks where the relationships between variables are non-linear, and               interpretability is essential.
# - Linear Regression: Linear regression is commonly used for predicting continuous numerical values when there is a linear         relationship between the features and the target variable.
#
# Summary
# - Decision trees supports non linearity, where LR supports only linear solutions.
# - When there are large number of features with less data-sets(with low noise), linear regressions may outperform Decision         trees/random forests. In general cases, Decision trees will be having better average accuracy.
# - For categorical independent variables, decision trees are better than linear regression.
# - Decision trees handles colinearity better than LR.
#
# **Random Forest Models**
# Random forest models are models made up of multiple decision trees. Random forest is an extension of the bagging method. It utilizes bagging and feature randomness (variability in the features) to create an uncorrelated forest of decision trees.
#
# Benefits of Random Forest Models
# - It reduces the risk of overfitting
# - It helps provides flexibility i.e it helps estimate missing data while maintaining accuracy
# - It is easy to determine the feature importance
#
# Disadvantages of Random Forest Models
# - It could be a time-consuming process
# - It requires more computational resources
# - It is more difficult to interprete when compared to decision trees
#
# **Boosting**:
# Boosting is a method used in machine learning to reduce errors in predictive data analysis. A single machine learning model might make prediction errors depending on the accuracy of the training dataset. For example, if a cat-identifying model has been trained only on images of white cats, it may occasionally misidentify a black cat. Boosting tries to overcome this issue by training multiple models sequentially to improve the accuracy of the overall system. Boosting improves machine models' predictive accuracy and performance by converting multiple weak learners into a single strong learning model. (A weak learner is a model that gives better results than a random prediction in a classification problem or the mean in a regression problem. A strong learners are models that have arbitrarily good accuracy.)

# %% [markdown]
# **Methodology**
#
# My data has high dimensionality. is it linear or non-linear relationship? Why is EDA necessary? How to check for dimensionality and relationships between relevant variables. What are the possible algorithms that could be used for the machine learning model. What are the variables in the data? what variables are important for the model?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

sns.set_style("whitegrid")
# %matplotlib inline

# %% [markdown]
# **Exploratory Data Analysis**

# %%
 Df1 = pd.read_excel("C://Users//Hi//Desktop//Energy_Data.xlsx")
 Df1.head()
# Out:
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import files
uploaded = files.upload()
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-4211db0a-ecea-479f-9de5-499d084553f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4211db0a-ecea-479f-9de5-499d084553f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
Df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  datetime64[ns]
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
Df1.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
Df1.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'date'}>,
#         <Axes: title={'center': 'Appliances'}>,
#         <Axes: title={'center': 'lights'}>,
#         <Axes: title={'center': 'T1'}>, <Axes: title={'center': 'RH_1'}>],
#        [<Axes: title={'center': 'T2'}>, <Axes: title={'center': 'RH_2'}>,
#         <Axes: title={'center': 'T3'}>, <Axes: title={'center': 'RH_3'}>,
#         <Axes: title={'center': 'T4'}>],
#        [<Axes: title={'center': 'RH_4'}>, <Axes: title={'center': 'T5'}>,
#         <Axes: title={'center': 'RH_5'}>, <Axes: title={'center': 'T6'}>,
#         <Axes: title={'center': 'RH_6'}>],
#        [<Axes: title={'center': 'T7'}>, <Axes: title={'center': 'RH_7'}>,
#         <Axes: title={'center': 'T8'}>, <Axes: title={'center': 'RH_8'}>,
#         <Axes: title={'center': 'T9'}>],
#        [<Axes: title={'center': 'RH_9'}>,
#         <Axes: title={'center': 'T_out'}>,
#         <Axes: title={'center': 'Press_mm_hg'}>,
#         <Axes: title={'center': 'RH_out'}>,
# ...

# %%
Df1.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
Df1.duplicated().sum()
# Out:
# 0

# %%
Temperature = ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9']
mean_values = Df1[Temperature].mean()

# %%
mean_values.plot.bar()
Temp = mean_values.plot.bar()
Temp.set_ylim(0, 25)
# Out:
# (0.0, 25.0)

# %%
Humidity = ['RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9']
mean_values1 = Df1[Humidity].mean()
mean_values1.plot.bar()
Hum = mean_values1.plot.bar()
Hum.set_ylim(0, 60)
# Out:
# (0.0, 60.0)

# %%
mean_values1 #mean value of each humidity column
# Out:
# RH_1    40.259739
# RH_2    40.420420
# RH_3    39.242500
# RH_4    39.026904
# RH_5    50.949283
# RH_6    54.609083
# RH_7    35.388200
# RH_8    42.936165
# RH_9    41.552401
# dtype: float64

# %%
mean_values #mean value of each temperature column
# Out:
# T1    21.686571
# T2    20.341219
# T3    22.267611
# T4    20.855335
# T5    19.592106
# T6     7.910939
# T7    20.267106
# T8    22.029107
# T9    19.485828
# dtype: float64

# %%
Df1.plot.scatter(x='Appliances', y='lights') #both are dependent variables
# Out:
# <Axes: xlabel='Appliances', ylabel='lights'>

# %%
Df1.corr(numeric_only=True) #Correlation analysis to measure of the strength of the linear relationship between variables
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
corr_matrix = Df1.corr(numeric_only=True)
corr_matrix["Appliances"].sort_values(ascending=False) #relationships between variables are generally weak
# Out:
# Appliances     1.000000
# lights         0.197278
# T2             0.120073
# T6             0.117638
# T_out          0.099155
# Windspeed      0.087122
# RH_1           0.086031
# T3             0.085060
# T1             0.055447
# T4             0.040281
# T8             0.039572
# RH_3           0.036292
# T7             0.025801
# T5             0.019760
# RH_4           0.016965
# Tdewpoint      0.015353
# T9             0.010010
# RH_5           0.006955
# Visibility     0.000230
# rv1           -0.011145
# rv2           -0.011145
# Press_mm_hg   -0.034885
# RH_9          -0.051462
# RH_7          -0.055642
# RH_2          -0.060465
# RH_6          -0.083178
# RH_8          -0.094039
# RH_out        -0.152282
# Name: Appliances, dtype: float64

# %%
plt.figure(figsize = (25,20))
HeatMap = sns.heatmap(Df1.corr(), annot = True)
# Out:
# <ipython-input-7-3870fde86796>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   HeatMap = sns.heatmap(Df1.corr(), annot = True)

# %%
from pandas.plotting import scatter_matrix           #Visualization of the correlation and relationships between variables
attributes = ["Appliances", "T2", "T6", "T_out"]
scatter_matrix(Df1[attributes], figsize=(10, 8))
# Out:
# array([[<Axes: xlabel='Appliances', ylabel='Appliances'>,
#         <Axes: xlabel='T2', ylabel='Appliances'>,
#         <Axes: xlabel='T6', ylabel='Appliances'>,
#         <Axes: xlabel='T_out', ylabel='Appliances'>],
#        [<Axes: xlabel='Appliances', ylabel='T2'>,
#         <Axes: xlabel='T2', ylabel='T2'>,
#         <Axes: xlabel='T6', ylabel='T2'>,
#         <Axes: xlabel='T_out', ylabel='T2'>],
#        [<Axes: xlabel='Appliances', ylabel='T6'>,
#         <Axes: xlabel='T2', ylabel='T6'>,
#         <Axes: xlabel='T6', ylabel='T6'>,
#         <Axes: xlabel='T_out', ylabel='T6'>],
#        [<Axes: xlabel='Appliances', ylabel='T_out'>,
#         <Axes: xlabel='T2', ylabel='T_out'>,
#         <Axes: xlabel='T6', ylabel='T_out'>,
#         <Axes: xlabel='T_out', ylabel='T_out'>]], dtype=object)

# %%
Df1.plot(kind="scatter", x="T2", y="Appliances", alpha=0.1)
# Out:
# <Axes: xlabel='T2', ylabel='Appliances'>

# %%
Df1 ['Avg_Temperature'] = Df1[['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9']].mean(axis=1) #feature engineering for average temperature and Temperature range columns
Df1
# Out:
#                      date  Appliances  lights         T1       RH_1  \
# 0     2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1     2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2     2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3     2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4     2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                   ...         ...     ...        ...        ...
# 19730 2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731 2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732 2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733 2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734 2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...     RH_9  \
# ...

# %%
Df1['Temperature_Range'] = Df1[['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9']].max(axis=1) - Df1[['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9']].min(axis=1)
Df1
# Out:
#                      date  Appliances  lights         T1       RH_1  \
# 0     2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1     2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2     2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3     2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4     2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                   ...         ...     ...        ...        ...
# 19730 2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731 2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732 2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733 2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734 2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...      T_out  \
# ...

# %%
Df1.plot(kind="scatter", x="Avg_Temperature", y="Appliances", alpha=0.1)
# Out:
# <Axes: xlabel='Avg_Temperature', ylabel='Appliances'>

# %%
Df1.plot(kind="scatter", x="Temperature_Range", y="Appliances", alpha=0.1)
# Out:
# <Axes: xlabel='Temperature_Range', ylabel='Appliances'>

# %%
Df1 ['Avg_humidity'] = Df1[['RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9']].mean(axis=1) #feature engineering for average humidity and range of humidity columns
Df1
# Out:
#                      date  Appliances  lights         T1       RH_1  \
# 0     2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1     2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2     2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3     2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4     2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                   ...         ...     ...        ...        ...
# 19730 2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731 2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732 2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733 2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734 2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...     RH_9  \
# ...

# %%
Df1['Range_Humidity'] = Df1[['RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9']].max(axis=1) - Df1[['RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9']].min(axis=1)
Df1
# Out:
#                      date  Appliances  lights         T1       RH_1  \
# 0     2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1     2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2     2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3     2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4     2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                   ...         ...     ...        ...        ...
# 19730 2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731 2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732 2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733 2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734 2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...      T_out  \
# ...

# %%
Df1.plot(kind="scatter", x="Range_Humidity", y="Appliances", alpha=0.1)
# Out:
# <Axes: xlabel='Range_Humidity', ylabel='Appliances'>

# %%
Df1.plot(kind="scatter", x="Avg_humidity", y="Appliances", alpha=0.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **None of the engineered variables/features have a strong linear relationship with the target variable, this could be due to many appliances not directly influencing temperature changes**

# %% [markdown]
# **Construct a Decision Tree Model**

# %%
from sklearn.model_selection import train_test_split  #data is split into training and test datasets
X = Df1.drop(['date', 'Appliances'], axis = 1) #copies all the datasets except date and Appliances
y = Df1['Appliances'] #Appliances is the target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train.shape #checks shape of the train dataset
# Out:
# (13814, 27)

# %%
X_test.shape  #checks shape of the test dataset
# Out:
# (5921, 27)

# %%
y_train.shape
# Out:
# (13814,)

# %%
y_test.shape
# Out:
# (5921,)

# %%
from sklearn.tree import DecisionTreeRegressor
#create a decision tree regressor object
Df1_Reg = DecisionTreeRegressor(max_depth = 5, min_samples_leaf = 10, random_state = 40)
#fit decision tree regressor object with training data
Df1_Reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, random_state=40)

# %%
#Predictions from the model
y_pred = Df1_Reg.predict(X_test)
y_pred
# Out:
# array([114.89548955,  59.0861377 ,  95.34305317, ...,  59.0861377 ,
#         59.0861377 , 114.89548955])

# %%
#Calculation of the accuracy of the model
from sklearn.metrics import mean_squared_error
#compute test-set MSE
mse_Df1 = mean_squared_error(y_test, y_pred)
mse_Df1
# Out:
# 9167.984764314822

# %%
from sklearn.metrics import mean_absolute_error
mae_Df1 = mean_absolute_error(y_test, y_pred)
mae_Df1
# Out:
# 52.493638616263496

# %%
from sklearn import metrics
#model evaluation using r-square for decision tree regression
r_square = metrics.r2_score(y_test, y_pred)
print(r_square) #output suggests decision tree model may not be a strong predictor
# Out:
# 0.13266535784314626

# %%
#compute test-set RMSE
rmse_Df1 = mse_Df1**(1/2)
print(rmse_Df1)
# Out:
# 92.0116540305192

# %%
from sklearn import tree
tree.plot_tree(Df1_Reg, feature_names= Df1.columns.tolist(), fontsize=12, filled=True) #plots decision trees
# Out:
# [Text(0.44933035714285713, 0.9375, 'date <= 5.0\nsquared_error = 10567.944\nsamples = 13814\nvalue = 97.639'),
#  Text(0.22232142857142856, 0.8125, 'T_out <= 70.917\nsquared_error = 8180.018\nsamples = 10686\nvalue = 86.722'),
#  Text(0.12232142857142857, 0.6875, 'T2 <= 26.943\nsquared_error = 12400.249\nsamples = 2918\nvalue = 115.089'),
#  Text(0.07321428571428572, 0.5625, 'lights <= 47.917\nsquared_error = 11613.953\nsamples = 2830\nvalue = 111.191'),
#  Text(0.039285714285714285, 0.4375, 'RH_7 <= 31.15\nsquared_error = 10721.57\nsamples = 2757\nvalue = 108.426'),
#  Text(0.02142857142857143, 0.3125, 'lights <= 34.548\nsquared_error = 31434.182\nsamples = 36\nvalue = 256.389'),
#  Text(0.014285714285714285, 0.1875, 'RH_3 <= 31.91\nsquared_error = 10714.286\nsamples = 21\nvalue = 170.0'),
#  Text(0.007142857142857143, 0.0625, 'squared_error = 5505.785\nsamples = 11\nvalue = 241.818'),
#  Text(0.02142857142857143, 0.0625, 'squared_error = 4529.0\nsamples = 10\nvalue = 91.0'),
# ...

# %%
sns.histplot(y_test-y_pred, kde=True)
# Out:
# <Axes: xlabel='Appliances', ylabel='Count'>

# %% [markdown]
# **GridSearchCV (Hyperparameter Tuning for Decision Trees)**

# %%
#defining parameters
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
parameters = {'criterion': ['absolute_error', 'squared_error'],
              'max_depth': [2,6,8],
              'min_samples_split': [5, 10, 15],
              'max_leaf_nodes':[5, 10],
             }

# %%
#instance of grid search object created
regressor = DecisionTreeRegressor()
GS = GridSearchCV(regressor, parameters, cv=5, n_jobs=-1) #creates an object of GridSearch

# %%
#conduct grid search over the parameter space
import time
start_time = time.time()              #records the current time in seconds
GS.fit(X_train, y_train)             #fits the GridSearchCV object 'GS' to the training data (X_train and y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error'],
#                          'max_depth': [2, 6, 8], 'max_leaf_nodes': [5, 10],
#                          'min_samples_split': [5, 10, 15]})

# %%
duration = time.time() - start_time   #measure how long the grid search process takes to execute
print(duration)
# Out:
# 461.8097655773163

# %%
Best_parameter = GS.best_params_
print(Best_parameter)
# Out:
# {'criterion': 'squared_error', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_split': 5}

# %%
print("R-Squared::{}".format(GS.best_score_))
# Out:
# R-Squared::0.09952779832183156

# %%
model = GS.best_estimator_
y_pred2 = model.predict(X_test)
print('mse score: %.2f' % mean_squared_error(y_test,y_pred2))
print('mae score: %.2f' % mean_absolute_error(y_test,y_pred2))
r2 = r2_score(y_test, y_pred2)
print("r2: %.2f" % r2)
# Out:
# mse score: 9519.97
# mae score: 54.72
# r2: 0.10

# %% [markdown]
# **Prediction using Random Forest Regression**

# %%
from sklearn.ensemble import RandomForestRegressor
 
# create regressor object
Df1_randomforest = RandomForestRegressor(random_state=42, n_jobs=1, max_depth=5, n_estimators=50)
 
# fit the regressor with x and y data
Df1_randomforest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50, n_jobs=1, random_state=42)

# %%
#prediction from the model
Df1_randomforest_predict = Df1_randomforest.predict(X_test)
Df1_randomforest_predict
# Out:
# array([110.12397058,  61.97852306,  91.92931432, ...,  61.56154729,
#         62.85480424, 161.43480687])

# %%
#calculating the accuracy of the model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mse = mean_squared_error(y_test, Df1_randomforest_predict)
mae = mean_absolute_error(y_test, Df1_randomforest_predict)
r2 = r2_score(y_test, Df1_randomforest_predict)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 8738.109120451454
# Mean Absolute Error (MAE): 51.748203403270715
# R-squared (R2): 0.17333362326102042

# %% [markdown]
# **RandomSearchCV (Hyperparameter Tuning for Random Forest)**

# %%
#defining parameters
param_dist = {
    'n_estimators': [10, 50],
    'max_depth': [5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
#Instance of Random Search Object Created
rf_regressor = RandomForestRegressor()
#conduct random search over parameter space
random_search = RandomizedSearchCV(
    estimator= rf_regressor,
    param_distributions= param_dist,
    n_iter=10,  # Number of random combinations to try
    cv=5,        # Number of cross-validation folds
    random_state=42,
    n_jobs=-1    # Use all available CPU cores for parallel processing
)

# %%
import time
start_time = time.time()
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [5, 10],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [10, 50]},
#                    random_state=42)

# %%
duration = time.time() - start_time   #measure how long the grid search process takes to execute
print(duration)
# Out:
# 128.7842881679535

# %%
best_params = random_search.best_params_
best_params
# Out:
# {'n_estimators': 10,
#  'min_samples_split': 10,
#  'min_samples_leaf': 4,
#  'max_depth': 10,
#  'bootstrap': True}

# %%
best_score = random_search.best_score_
best_score
# Out:
# 0.31153161980112254

# %%
best_rf_model = random_search.best_estimator_
y_pred_randomsearch = best_rf_model.predict(X_test)
y_pred_randomsearch
# Out:
# array([107.17187072,  42.74940606,  65.84647059, ...,  56.52776266,
#         60.71726906, 293.01810345])

# %%
print('mse score: %.2f' % mean_squared_error(y_test,y_pred_randomsearch))
print('mae score: %.2f' % mean_absolute_error(y_test,y_pred_randomsearch))
r2 = r2_score(y_test, y_pred_randomsearch)
print("r2: %.2f" % r2 )
# Out:
# mse score: 7046.93
# mae score: 43.83
# r2: 0.33

# %% [markdown]
# # **Prediction Using Boosting Algorithms**

# %% [markdown]
# **Prediction Using Adaboost**

# %%
from sklearn.ensemble import AdaBoostRegressor
# Create an AdaBoostRegressor with a DecisionTreeRegressor as the base estimator
base_estimator = DecisionTreeRegressor(max_depth=6) #This is the Weak learner (decision tree)
ada_reg = AdaBoostRegressor(base_estimator=base_estimator, n_estimators=50, learning_rate=0.1, random_state=42) #This is the Adaboost regressor
print(ada_reg)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=6),
#                   learning_rate=0.1, random_state=42)

# %%
Ada1 =ada_reg.fit(X_train, y_train)
# Out:
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_predict1 = Ada1.predict(X_test)
y_predict1
# Out:
# array([125.39101498,  78.4009009 ,  91.75097276, ...,  79.75224775,
#         78.6451313 , 264.60869565])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_predict1)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_predict1)
r2 = r2_score(y_test, y_predict1)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 8425.595624251633
# Root Mean Squared Error (RMSE): 91.79104326812956
# Mean Absolute Error (MAE): 63.131007207581824
# R-squared (R2): 0.20289887542534568

# %% [markdown]
# **Prediction Using Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingRegressor
Boost_reg = GradientBoostingRegressor(max_depth = 6, n_estimators=50, learning_rate=0.1, random_state=42) #GradientBoostingRegressor model is created and assigned to the variable 'Boost_reg'.
Boost_reg.fit(X_train, y_train) #fits the model to the training data
Boost_reg.predict(X_test) #prediction using the trained model on the test data
Boost_reg.score(X_test, y_test) #calculates and returns the R-squared score
# Out:
# 0.3496204930599326

# %%
B = Boost_reg.predict(X_test) #prediction using the trained model on the test data
B
# Out:
# array([ 94.9066294 ,  41.66337742,  77.74524324, ...,  57.72214134,
#         53.59893294, 246.74639577])

# %%
mse = mean_squared_error(y_test, B) #calculates the mean squared error
print("The mean squared error (MSE) on test set: {:.4f}".format(mse)) #prints the mean squared error
mae = mean_absolute_error(y_test, B) # Calculates the MAE score
print("Mean Absolute Error (MAE):", mae) # Print the MAE as needed
rmse = np.sqrt(mse) #calculates the Root Mean Square Error
print("RMSE : % f" %(rmse)) #prints the Root Mean Square Error
r2 = r2_score(y_test, B)  #prints the the R-squared score
print("R-squared (R2):", r2)
# Out:
# The mean squared error (MSE) on test set: 6874.7045
# Mean Absolute Error (MAE): 43.362393563339154
# RMSE :  82.913838
# R-squared (R2): 0.3496204930599326

# %% [markdown]
# **Prediction Using XGBoost**

# %%
# !pip install xgboost #installls the XGBoost library

# %%
import xgboost as xgb #imports the package
Xg_boost = xgb.XGBRegressor(objective = "reg:squarederror", n_estimators = 50, learning_rate=0.1, max_depth = 6, random_state = 42) #Builds the xgboost model
Xg_boost.fit(X_train, y_train) #fits the model to the training data
x = Xg_boost.predict(X_test) #predicts using the test data
x
# Out:
# array([102.107376,  45.167263,  75.288376, ...,  81.6677  ,  53.88836 ,
#        261.44574 ], dtype=float32)

# %%
#metrics calculations
from sklearn.metrics import r2_score
mse = mean_squared_error(y_test, x)
print("Mean Squared Error (MSE):", mse)
mae = mean_absolute_error(y_test, x)
print(f"Mean Absolute Error (MAE): {mae}")
rmse = np.sqrt(mse)
print("RMSE : % f" %(rmse))
r2 = r2_score(y_test, x)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 6623.8153554867995
# Mean Absolute Error (MAE): 41.913275554562276
# RMSE :  81.386825
# R-squared (R2): 0.3733557953296208

# %% [markdown]
# **Hyperparameter Tuning for XGBoost**

# %%
param_dist = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'learning_rate': [0.3],
    'reg_lambda': [1],
    'reg_alpha': [1],
    'random_state': [42]
}

# %%
# Create an XGBoost regressor
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse')

# %%
random_search = RandomizedSearchCV(
    xgb_model,
    param_distributions=param_dist,
    n_iter=100, 
    cv=5, 
    n_jobs=-1,  # Use all available CPU cores
    random_state=42
)

# %%
# Fit the RandomizedSearchCV
random_search.fit(X_train, y_train)
# Get the best hyperparameters
best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# C:\Users\Hi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'reg_lambda': 1, 'reg_alpha': 1, 'random_state': 42, 'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.3}

# %%
XGBR_Best_parameter = random_search.best_params_
print(XGBR_Best_parameter)
# Out:
# {'reg_lambda': 1, 'reg_alpha': 1, 'random_state': 42, 'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.3}

# %%
XGB_Random = random_search.best_estimator_
y_pred3 = XGB_Random.predict(X_test)
print('mse score: %.2f' % mean_squared_error(y_test,y_pred3))
print('mae score: %.2f' % mean_absolute_error(y_test,y_pred3))
print('computation time: %.2f' % duration)
# Out:
# mse score: 5460.61
# mae score: 35.70
# computation time: 461.81

# %%
print("R-Squared::{}".format(random_search.best_score_))
# Out:
# R-Squared::0.4770888484363491
